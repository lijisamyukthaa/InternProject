# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/headbrain.csv")
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               237 non-null    int64
#  1   Age Range            237 non-null    int64
#  2   Head Size(cm^3)      237 non-null    int64
#  3   Brain Weight(grams)  237 non-null    int64
# dtypes: int64(4)
# memory usage: 7.5 KB

# %%
df.describe()
# Out:
#            Gender   Age Range  Head Size(cm^3)  Brain Weight(grams)
# count  237.000000  237.000000       237.000000           237.000000
# mean     1.434599    1.535865      3633.991561          1282.873418
# std      0.496753    0.499768       365.261422           120.340446
# min      1.000000    1.000000      2720.000000           955.000000
# 25%      1.000000    1.000000      3389.000000          1207.000000
# 50%      1.000000    2.000000      3614.000000          1280.000000
# 75%      2.000000    2.000000      3876.000000          1350.000000
# max      2.000000    2.000000      4747.000000          1635.000000

# %%
X = df[['Head Size(cm^3)']].values
y = df[['Brain Weight(grams)']].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg=reg.fit(X_train,y_train)
y_pred=reg.predict(X_test)
y_pred=reg.predict(X_test)

# %%
from matplotlib import pyplot as plt
plt.scatter(X_test,y_test,color="blue")
plt.plot(X_test,y_pred,color="red")

# %%
res=y_pred - y_test
plt.scatter(X_test,res,color="blue")
plt.plot(X_test,[0]*len(y_pred-1),color="red")

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("RMSE:",rmse)
# Out:
# MSE: 5213.883492966196
# RMSE: 72.20722604397842

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print("R2 Score:",r2)
# Out:
# R2 Score: 0.6067679928496792

# %%
reg.predict([[3352]])
# Out:
# array([[1207.05028324]])

# %%
reg.predict([[4500]])
# Out:
# array([[1520.33716246]])

# %%
plt.hist(df['Head Size(cm^3)'], bins=15, color='skyblue', edgecolor='black')
plt.xlabel('Head Size (cm³)')
plt.ylabel('Frequency')
plt.title('Distribution of Head Size')
plt.tight_layout()
plt.show()

# %%
plt.boxplot([df['Head Size(cm^3)'], df['Brain Weight(grams)']])
plt.xticks([1, 2], ['Head Size', 'Brain Weight'])
plt.title('Box Plot of Head Size and Brain Weight')
plt.tight_layout()
plt.show()
